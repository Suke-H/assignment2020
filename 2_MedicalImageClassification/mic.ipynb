# %% [markdown]
# # 2. 医用画像分類

# %%
import numpy as np
from PIL import Image
import os
import sys
from glob import glob
import cv2
import re

import keras
from keras.models import Sequential, Input, Model
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPooling2D, Lambda
from keras.optimizers import Adam
from keras import backend as K

# %% [markdown]
# ## 画像の読み込み

# %%
# 画像のnumpy形式と対応する正解ラベルを返す関数
def readImg(paths):

  N = len(paths)

  # 画像読み込み準備
  imgs = [[] for i in range(N)]
  # 正解データ作成
  imgs_targets = []

  for k, path in enumerate(paths):
    
    #label = 画像が入ってるフォルダ名
    label = os.path.basename(os.path.dirname(path))

    if label == "0":
	    imgs_targets.append(0)
    else:
      imgs_targets.append(1)

    imgs[k] = np.array(Image.open(path))

    sys.stderr.write('{}枚目\r'.format(k))
    sys.stderr.flush()

  sys.stderr.write('\n')

  imgs = np.array(imgs, dtype = "float32")
  imgs_targets = np.array(imgs_targets, dtype = "int32")

  return imgs, imgs_targets

# %%
# データセットのあるパス
main_path = "/content/drive/My Drive/Colab Notebooks/Dataset/"
train_path = main_path + "train/"
val_path = main_path + "val/"
test_path = main_path + "test/"

# 全画像のパス読み込み
train_paths = np.array(sorted(glob(train_path + "**/*.png"),
                              key=lambda s: int(re.findall(r'\d+', s)[len(re.findall(r'\d+', s))-1])))
val_paths = np.array(sorted(glob(val_path + "**/*.png"),
                            key=lambda s: int(re.findall(r'\d+', s)[len(re.findall(r'\d+', s))-1])))
test_paths = np.array(sorted(glob(test_path + "**/*.png"),
                             key=lambda s: int(re.findall(r'\d+', s)[len(re.findall(r'\d+', s))-1])))

print(len(train_paths), len(val_paths), len(test_paths))
print(val_paths)
# Out:
# 8980 1448 2458
# ['/content/drive/My Drive/Colab Notebooks/Dataset/val/0/1.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/val/0/2.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/val/0/3.png' ...
#  '/content/drive/My Drive/Colab Notebooks/Dataset/val/0/2198.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/val/0/2199.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/val/0/2200.png']

# %% [markdown]
# ## 初めて画像を読み込むときに使用．
# 一度npy形式に保存したら以下のセルをコメントアウト推奨．

# %%
# # 画像読み込み
# x_train, y_train = readImg(train_paths)
# x_val, y_val = readImg(val_paths)
# x_test, y_test = readImg(test_paths)
 
# print(x_train.shape, y_train.shape, x_val.shape, y_val.shape, x_test.shape, y_test.shape)

# # npy形式で保存
# np.save(main_path + "x_train", x_train)
# np.save(main_path + "y_train", y_train)
# np.save(main_path + "x_val", x_val)
# np.save(main_path + "y_val", y_val)
# np.save(main_path + "x_test", x_test)
# np.save(main_path + "y_test", y_test)

# %% [markdown]
# ## npy形式から読み込み

# %%
# npy形式から読み込み
x_train, y_train = np.load(main_path + "x_train.npy"), np.load(main_path + "y_train.npy")
x_val, y_val = np.load(main_path + "x_val.npy"), np.load(main_path + "y_val.npy")
x_test, y_test = np.load(main_path + "x_test.npy"), np.load(main_path + "y_test.npy")

print(x_train.shape, x_val.shape, x_test.shape)
# Out:
# (8980, 224, 224) (1448, 224, 224) (2458, 224, 224)

# %% [markdown]
# ## 画像の前処理

# %%
# 正規化
x_train /= 255.0
x_val /= 255.0
x_test /= 255.0

# 訓練データをシャッフル
perm = np.random.permutation(x_train.shape[0])
x_train, y_train = x_train[perm], y_train[perm]

# %% [markdown]
# ## ディープラーニングによる画像分類
#
# CNNモデルを用いて画像分類を行う．
# グレースケール画像なので，CNNに通す前に次元を増やす必要がある．

# %%
# パラメータ
num_classes = 2
img_rows, img_cols, channel = 224, 224, 1

# 検証用の正解ラベルを保存しておく
true_labels = y_test[:]

# 正解ラベルをone-hotに変換
y_train = keras.utils.to_categorical(y_train, num_classes)
y_val = keras.utils.to_categorical(y_val, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# CNN用に次元を追加
if K.image_data_format() == 'channels_first':
    x_train = x_train.reshape(x_train.shape[0], channel, img_rows, img_cols)
    x_val = x_val.reshape(x_val.shape[0], channel, img_rows, img_cols)
    x_test = x_test.reshape(x_test.shape[0], channel, img_rows, img_cols)
    input_shape = (channel, img_rows, img_cols)
else:
    x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, channel)
    x_val = x_val.reshape(x_val.shape[0], img_rows, img_cols, channel)
    x_test = x_test.reshape(x_test.shape[0], img_rows, img_cols, channel)
    input_shape = (img_rows, img_cols, channel)

# %% [markdown]
# ## モデル定義
# モデルはhttps://qiita.com/wataoka/items5c6766d3e1c674d61425  を参照
# 損失関数はbinary_crossentropy, 最適化アルゴリズムはAdadeltaを使用

# %%
def model_net():

    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                    activation='relu',
                    input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(num_classes, activation='softmax'))
    
    return model

# 学習済みモデルがあったら読み込み
if os.path.exists(main_path + 'models/model_net.h5'):
    model = keras.models.load_model(main_path + 'models/model_net.h5', compile=False)
    print("モデル読み込み")

# なかったら新しく定義
else:
    model = model_net()
    print("モデル新規作成")

# モデル出力
print(model.summary())

# モデルの設定
model.compile(loss=keras.losses.binary_crossentropy,
              optimizer=keras.optimizers.Adadelta(),
              metrics=['accuracy'])
# Out:
# モデル読み込み
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 222, 222, 32)      320
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 220, 220, 64)      18496
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 110, 110, 64)      0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 110, 110, 64)      0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 774400)            0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               99123328
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 99,142,402
# Trainable params: 99,142,402
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# パラメータ
batch_size, epochs = 128, 50

# # 学習
# stack = model.fit(x_train, y_train,
#                   batch_size=batch_size,
#                   epochs=epochs,
#                   verbose=1,
#                   validation_data=(x_val, y_val))

# モデルの保存
model.save(main_path + 'models/model_net.h5', include_optimizer=False)

# %%
# 評価
score = model.evaluate(x_test, y_test, verbose=1)
print(list(zip(model.metrics_names, score)))

# 検証データから推定したラベルを出力
predict_labels = model.predict_classes(x_test)

# 推定ラベルと正解ラベルの組を入力し, 混合行列confusion_mおよび各組に対するラベルconfusion_lを返す
# confusion_m = [TP, TN, FP, FN]
# confusion_l = [0, 3, 1, ...](TP=0, TN=1, FP=2, FN=3)
def make_confusion_m(predict_labels, true_labels):
    confusion_m = np.array([0, 0, 0, 0])
    confusion_l = []

    for (true, pred) in zip(true_labels, predict_labels):
        # TP
        if true==True and pred==True:
            confusion_m[0] += 1
            confusion_l.append(0)
        
        # TN
        elif true==False and pred==False:
            confusion_m[1] += 1
            confusion_l.append(1)

        # FP
        elif true==False and pred==True:
            confusion_m[2] += 1
            confusion_l.append(2)

        # FN
        elif true==True and pred==False:
            confusion_m[3] += 1
            confusion_l.append(3)

    return confusion_m, np.array(confusion_l)

# 混合行列
confusion_m, confusion_l = make_confusion_m(predict_labels, true_labels)
print(confusion_m)

# 不正解の検証データのインデックスを取り出す
negative_indices = np.where(confusion_l >= 2)
print(negative_indices)

# 不正解の検証データ
negative_files = test_paths[negative_indices]
print(negative_files)
# Out:
# 2458/2458 [==============================] - 2s 736us/step
# [('loss', 0.5612095584689379), ('accuracy', 0.8913751244544983)]
# [1151 1040  155  112]
# (array([  13,   14,   16,   17,   18,   19,   20,   21,   22,   23,  113,
#         114,  115,  116,  147,  165,  191,  209,  266,  342,  346,  354,
#         355,  356,  357,  358,  359,  360,  362,  363,  425,  458,  460,
#         488,  489,  490,  491,  492,  493,  494,  495,  496,  520,  521,
#         522,  523,  575,  582,  583,  590,  591,  592,  593,  594,  595,
#         596,  618,  619,  620,  621,  622,  623,  624,  625,  626,  627,
#         628,  629,  630,  648,  649,  685,  696,  721,  722,  723,  724,
#         725,  726,  727,  728,  729,  730,  731,  732,  733,  734,  735,
#         736,  747,  769,  790,  791,  792,  793,  794,  847,  854,  863,
#         871,  872,  873,  877,  883,  892,  897,  898,  899,  900,  901,
#         902,  904,  905,  906,  907,  908,  909,  910,  911,  912,  913,
#         915,  918,  919,  920,  921,  943,  967,  973, 1004, 1053, 1054,
#        1058, 1059, 1060, 1061, 1062, 1065, 1066, 1068, 1071, 1072, 1073,
#        1074, 1075, 1076, 1077, 1078, 1103, 1157, 1168, 1187, 1188, 1189,
#        1190, 1195, 1225, 1226, 1252, 1253, 1256, 1257, 1258, 1259, 1260,
#        1269, 1270, 1272, 1273, 1285, 1286, 1287, 1288, 1289, 1290, 1291,
#        1300, 1301, 1302, 1349, 1350, 1351, 1398, 1399, 1463, 1503, 1567,
#        1568, 1569, 1570, 1613, 1614, 1615, 1641, 1659, 1660, 1661, 1662,
#        1663, 1664, 1665, 1666, 1667, 1668, 1670, 1671, 1672, 1673, 1676,
#        1734, 1775, 1778, 1813, 1814, 1815, 1816, 1817, 1818, 1819, 1820,
#        1823, 1883, 1914, 1941, 1942, 1943, 1947, 1948, 1949, 1979, 2019,
#        2020, 2021, 2051, 2052, 2093, 2094, 2099, 2100, 2101, 2119, 2153,
#        2202, 2203, 2204, 2205, 2206, 2207, 2208, 2246, 2337, 2339, 2341,
#        2342, 2343, 2344, 2345, 2346, 2377, 2394, 2395, 2396, 2397, 2398,
#        2409, 2410, 2457]),)
# ['/content/drive/My Drive/Colab Notebooks/Dataset/test/1/47.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/48.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/50.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/51.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/52.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/53.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/54.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/55.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/56.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/57.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/230.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/231.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/232.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/233.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/264.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/339.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/399.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/454.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/546.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/649.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/653.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/661.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/662.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/663.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/664.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/665.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/666.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/667.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/669.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/670.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/881.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/922.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/924.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/952.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/953.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/954.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/955.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/956.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/957.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/958.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/959.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/960.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1001.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1014.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1015.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1016.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1079.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1095.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1096.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1103.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1104.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1117.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1118.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1119.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1120.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1121.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1143.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1169.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1170.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1171.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1172.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1173.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1174.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1175.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1176.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1177.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1178.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1179.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1180.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1198.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1199.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1303.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1314.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1357.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1358.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1359.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1360.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1361.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1362.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1363.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1364.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1365.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1366.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1367.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1368.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1369.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1370.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1371.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1372.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1403.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1462.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1483.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1484.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1485.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1486.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1501.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1570.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1587.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1596.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1621.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1622.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1623.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1627.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1633.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1642.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1647.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1648.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1649.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1650.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1651.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1652.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1654.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1655.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1656.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1657.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1658.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1659.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1660.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1661.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1662.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1663.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1665.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1668.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1669.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1670.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1671.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1709.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1755.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1761.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/1881.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1938.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1939.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1943.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1944.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1945.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1946.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1947.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1950.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1951.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1953.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1956.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1957.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1958.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1959.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1960.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1961.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1962.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1963.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/1988.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2054.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2085.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2104.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2105.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2106.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2107.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2112.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2257.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2258.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2308.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2309.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2362.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2363.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2364.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2365.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2366.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2375.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2376.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2378.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2379.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2391.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2392.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2393.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2394.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2395.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2396.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2397.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2406.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2407.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2408.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2528.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2529.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2530.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2597.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2598.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2696.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2783.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2888.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2889.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2890.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2891.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2948.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2949.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/2950.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/2991.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3020.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3021.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3022.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3023.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3024.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3025.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3026.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3027.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3028.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3029.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3031.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3032.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3033.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3034.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3037.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3110.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3172.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3175.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3273.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3274.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3275.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3276.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3277.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3278.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3279.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3280.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3283.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3398.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3439.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3500.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3501.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3502.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3520.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3521.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3522.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3609.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3658.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3659.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3660.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3706.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3707.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3810.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3811.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3816.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3817.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3818.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/3854.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/3904.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4060.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4061.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4062.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4063.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4064.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4065.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4066.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4104.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4230.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4232.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4234.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4235.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4236.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4237.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4238.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4239.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4290.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4307.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4308.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4309.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4310.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4311.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4322.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/0/4323.png'
#  '/content/drive/My Drive/Colab Notebooks/Dataset/test/1/4383.png']
